# %%
#importing libraries
import requests

# %%
from bs4 import BeautifulSoup

# %%
from collections import Counter

# %%
import matplotlib.pyplot as plt

# %%
# to get data from given url
webdata=requests.get( 'https://en.wikipedia.org/wiki/Machine_learning')

# %%
webdata    # will give response only
# Out:
# <Response [200]>

# %%
htmldata=webdata.text

# %%
htmldata    # html data of url
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Machine learning - Wikipedia</title>\n<script>document.documentElement.className=document.documentElement.className.replace(/(^|\\s)client-nojs(\\s|$)/,"$1client-js$2");RLCONF={"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Machine_learning","wgTitle":"Machine learning","wgCurRevisionId":904871834,"wgRevisionId":904871834,"wgArticleId":233488,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["CS1 maint: Multiple names: authors list","CS1 maint: others","Wikipedia articles needing clarification from November 2018","Commons category link from Wikidata","Machine learning","Cybernetics","Learning"],"wgBreakFrames":!1,"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthN
# ...

# %%
soup=BeautifulSoup(htmldata,'html.parser')   # parser

# %%
# cleaning that data for readable form
clean_data=soup.get_text()

# %%
clean_data
# Out:
# '\n\n\n\nMachine learning - Wikipedia\ndocument.documentElement.className=document.documentElement.className.replace(/(^|\\s)client-nojs(\\s|$)/,"$1client-js$2");RLCONF={"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Machine_learning","wgTitle":"Machine learning","wgCurRevisionId":904871834,"wgRevisionId":904871834,"wgArticleId":233488,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["CS1 maint: Multiple names: authors list","CS1 maint: others","Wikipedia articles needing clarification from November 2018","Commons category link from Wikidata","Machine learning","Cybernetics","Learning"],"wgBreakFrames":!1,"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","Dec
# ...

# %%
clean_data=clean_data.replace('\n',' ')

# %%
clean_data=clean_data.replace('.',' ')
clean_data
# Out:
# '    Machine learning - Wikipedia document documentElement className=document documentElement className replace(/(^|\\s)client-nojs(\\s|$)/,"$1client-js$2");RLCONF={"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Machine_learning","wgTitle":"Machine learning","wgCurRevisionId":904871834,"wgRevisionId":904871834,"wgArticleId":233488,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["CS1 maint: Multiple names: authors list","CS1 maint: others","Wikipedia articles needing clarification from November 2018","Commons category link from Wikidata","Machine learning","Cybernetics","Learning"],"wgBreakFrames":!1,"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December
# ...

# %%
# to count all the words after scraping
count=0
list2=clean_data.split(" ")
for words in list2:
  count=count+1
print(count)
# Out:
# 10604

# %%
# removing spaces from the list
while ('' in list2):
  list2.remove('')

# %%
# creating dictionary for representation of repeation of words
ls=[]
for i in list2:
  word_count = list2.count(i)   # Pythons count function 
  ls.append((i,word_count))       


diction = dict(ls)
print(diction)
# Out:
# {'Machine': 60, 'learning': 186, '-': 3, 'Wikipedia': 3, 'document': 1, 'documentElement': 2, 'className=document': 1, 'className': 1, 'replace(/(^|\\s)client-nojs(\\s|$)/,"$1client-js$2");RLCONF={"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Machine_learning","wgTitle":"Machine': 1, 'learning","wgCurRevisionId":904871834,"wgRevisionId":904871834,"wgArticleId":233488,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["CS1': 1, 'maint:': 6, 'Multiple': 3, 'names:': 3, 'authors': 3, 'list","CS1': 1, 'others","Wikipedia': 1, 'articles': 3, 'needing': 3, 'clarification': 2, 'from': 53, 'November': 4, '2018","Commons': 1, 'category': 3, 'link': 2, 'Wikidata","Machine': 1, 'learning","Cybernetics","Learning"],"wgBreakFrames":!1,"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgM
# ...

# %%
# creation of dictionary of top20 words
list1=[]
k=Counter(diction)
high=k.most_common(20)
for i in high:
  list1.append((i[0],i[1]))
list1=dict(list1)
print(list1)
# Out:
# {'the': 302, 'of': 238, 'and': 198, 'a': 197, 'to': 187, 'learning': 186, 'in': 135, 'is': 96, '^': 83, 'machine': 80, 'that': 76, 'data': 65, 'Machine': 60, 'are': 60, 'from': 53, 'for': 53, 'on': 52, 'algorithms': 51, 'as': 51, 'training': 43}

# %%
# pie chart of top 20 repeated words
plt.figure(figsize=(5,8))
plt.pie(list1.values(),labels=list(list1.keys()),autopct='%1.1f%%')
plt.show()

# %%
# bar graph of top 20 repeated words
plt.figure(figsize=(12,5))
plt.bar(range(len(list1)), list1.values(),width=0.2)
plt.xticks(range(len(list1)), list(list1.keys()))
plt.show()

# %%
ls2=[]
for i in ls:
  if i[1]>3:
    ls2.append((i[0],i[1]))

diction2=dict(ls2)

# %%
# scatter graph for words repeated more than 3 times
from matplotlib.pyplot import figure
plt.figure(num=None,figsize=(5,5),dpi=80)
for keys,values in diction2.items():
  x=keys
  y=values
  plt.scatter(x,y)

# %%
# total no. of links in the url
for Alink in soup.find_all('a'):
  count += 1
  Alink.get('href')
print(count)
# Out:
# 11862
